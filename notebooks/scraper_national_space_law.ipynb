# %% [markdown]
# ## Scraping a list of all national space law available at UNOOSA
#
# Taken from here: http://www.unoosa.org/oosa/en/ourwork/spacelaw/nationalspacelaw/

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %matplotlib inline
pd.set_option('max_colwidth', -1)

from user_agent import generate_user_agent
headers = {'User-Agent': generate_user_agent(device_type="desktop", os=('mac', 'linux'))}

# %%
url = 'http://www.unoosa.org/oosa/en/ourwork/spacelaw/nationalspacelaw/'

raw_html = requests.get(url, headers=headers)
soup_doc = BeautifulSoup(raw_html.content, 'html.parser')

# %%
soup_doc.findAll('h3')[0].next_sibling.next
# Out:
# <ul>
# <li>
# <strong>National Decree No. 995/91, Creation of the National Commission on Space Activities (28 May 1991)</strong>
# <ul>
# <li>
# <a href="http://www.conae.gov.ar/images/legislacion/l99591.pdf">Spanish version</a> (external link) [
#     <em>link verified 23 June 2014</em>]</li>
# </ul></li>
# <li>
# <strong>National Decree No. 125/95, Establishment of the National Registry of Objects Launched into Outer Space (25 July 1995)</strong>
# <br/>
# <ul>
# <li>
# <a href="http://www.conae.gov.ar/images/legislacion/l12595.pdf">Spanish version</a> (external link) [
#       <em>link verified 23 June 2014</em>]</li>
# </ul>
# </li>
# </ul>

# %%
national_law_list = [] 

# Iterate through each country with a national space law
for country in soup_doc.findAll('h3')[:-3]:
    law_dict = {}
    if country.string == None:
        law_dict['country'] = 'Austria'
    else:
        law_dict['country'] = country.string
    print('------------------------', law_dict['country'])

    # Iterate through each law in said country
    for law in country.next_sibling.next.findAll('li'):
        for each in law.findAll('strong'):
            print(each.text)
            law_dict['name'] = each.text
            national_law_list.append(law_dict)
# Out:
# ------------------------ Argentina
# National Decree No. 995/91, Creation of the National Commission on Space Activities (28 May 1991)
# National Decree No. 125/95, Establishment of the National Registry of Objects Launched into Outer Space (25 July 1995)
# ------------------------ Australia
# Space Activities Act 1998 (No. 123, 1998) (as amended, taking into account amendments up to Act No. 8 of 2010)
# Space Activities Regulations 2001)
# ------------------------ Austria
# Authorization of Space Activities and the Estabishment of a National Space Registry (Austrian Outer Space Act)
# ------------------------ Belgium
# Law on the Activities of Launching, Flight Operations or Guidance of Space Objects
#
# ------------------------ Brazil
# Law No. 8.854 of 10 February 1994, Law Establishing the Brazilian Space Agency
#
# ------------------------ Canada
# Canadian Space Agency Act
#
# Canadian Aviation Regulations: sections 602.43 and 602.44
#
# Civil International Space Station Agreement Implementation Act (S.C. 1999, c. 35)
#
# Remote Sensing Space Systems Act (S.C. 2005, c. 45)
#
# Remote Sensing Space Systems Regulations (SOR/2007-66)
#
# Radiocommunication Act (R.S.C., 1985, c. R-2)
#
# ------------------------ Chile
# Supreme Decree No. 338: Establishment of a Presidential Advisory Committee known as the Chilean Space Agency
#
# ------------------------ China
# China's Space Activities (White Paper of 2003)
#
# ------------------------ France
# Decree 62-153, Regulations Relating to the CNES
# Law No. 61-1382, 20 December 1961 Statute of the Centre National d'Etudes Spatiales (CNES)
# Decree 89-508 & Decree 90-1102 , concerning the Space Committee
# ------------------------ Germany
# Law governing the transfer of responsibilities for space activities
#
# Act to give Protection against the Security Risk to the Federal Republic of Germany by the Dissemination of High-Grade Earth Remote Sensing Data
# Law governing the transfer of administrative functions in the sector of outer space activities
#
# Decree of the President of Ukraine on Regulations for the National Space Agency of Ukraine (22 July 1997, No. 665/97)
#
# Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment
# ------------------------ United Kingdom of Great Britain and Northern Ireland
# OUTER SPACE ACT (United Kingdom, 1986)
#
# ------------------------ United States of America
# United States Code, United States Code, Title 51 - National and Commercial Space Programs
#
# 35 USC Chapter 10, Sect. 105, Inventions in outer space

# %%
national_law_list
# Out:
# [{'country': 'Argentina',
#   'name': 'National Decree No. 125/95, Establishment of the National Registry of Objects Launched into Outer Space (25 July 1995)'},
#  {'country': 'Argentina',
#   'name': 'National Decree No. 125/95, Establishment of the National Registry of Objects Launched into Outer Space (25 July 1995)'},
#  {'country': 'Australia', 'name': 'Space Activities Regulations 2001)'},
#  {'country': 'Australia', 'name': 'Space Activities Regulations 2001)'},
#  {'country': 'Austria',
#   'name': 'Authorization of Space Activities and the Estabishment of a National Space Registry (Austrian Outer Space Act)'},
#  {'country': 'Belgium',
#   'name': 'Law on the Activities of Launching, Flight Operations or Guidance of Space Objects\n  '},
#  {'country': 'Brazil',
#   'name': 'Law No. 8.854 of 10 February 1994, Law Establishing the Brazilian Space Agency\n  '},
#  {'country': 'Canada',
#   'name': 'Radiocommunication Act (R.S.C., 1985, c. R-2)\n  '},
#  {'country': 'Canada',
#   'name': 'Radiocommunication Act (R.S.C., 1985, c. R-2)\n  '},
#  {'country': 'Canada',
#   'name': 'Radiocommunication Act (R.S.C., 1985, c. R-2)\n  '},
#  {'country': 'Canada',
#   'name': 'Radiocommunication Act (R.S.C., 1985, c. R-2)\n  '},
#  {'country': 'Canada',
#   'name': 'Radiocommunication Act (R.S.C., 1985, c. R-2)\n  '},
#  {'country': 'Canada',
#   'name': 'Radiocommunication Act (R.S.C., 1985, c. R-2)\n  '},
#  {'country': 'Chile',
#   'name': 'Supreme Decree No. 338: Establishment of a Presidential Advisory Committee known as the Chilean Space Agency\n  '},
#  {'country': 'China',
#   'name': "China's Space Activities (White Paper of 2003)\n  "},
#  {'country': 'France',
#   'name': 'Decree 89-508 & Decree 90-1102 , concerning the Space Committee'},
#  {'country': 'France',
#   'name': 'Decree 89-508 & Decree 90-1102 , concerning the Space Committee'},
#  {'country': 'France',
#   'name': 'Decree 89-508 & Decree 90-1102 , concerning the Space Committee'},
#  {'country': 'Germany', 'name': 'Satellite Data Security Act'},
#  {'country': 'Germany', 'name': 'Satellite Data Security Act'},
#  {'country': 'Germany', 'name': 'Satellite Data Security Act'},
#  {'country': 'Germany', 'name': 'Satellite Data Security Act'},
#  {'country': 'Germany', 'name': 'Satellite Data Security Act'},
#  {'country': 'Japan',
#   'name': 'Law Concerning The National Space Development Agency Of Japan (Law No. 50 of June 23, 1969, as amended)\n  '},
#  {'country': 'Kazakhstan',
#   'name': 'Law of the Republic of Kazakhstan on Space Activities (No.528-IV of 6 January 2012)\n  '},
#  {'country': 'Netherlands',
#   'name': 'Order by the Minister of Economic Affairs of 26 June 2015, no. WJZ/15055654, amending the Space Activities Licence Application and Registration Order, in connection with changes to the application form'},
#  {'country': 'Netherlands',
#   'name': 'Order by the Minister of Economic Affairs of 26 June 2015, no. WJZ/15055654, amending the Space Activities Licence Application and Registration Order, in connection with changes to the application form'},
#  {'country': 'Netherlands',
#   'name': 'Order by the Minister of Economic Affairs of 26 June 2015, no. WJZ/15055654, amending the Space Activities Licence Application and Registration Order, in connection with changes to the application form'},
#  {'country': 'Netherlands',
#   'name': 'Order by the Minister of Economic Affairs of 26 June 2015, no. WJZ/15055654, amending the Space Activities Licence Application and Registration Order, in connection with changes to the application form'},
#  {'country': 'Netherlands',
#   'name': 'Order by the Minister of Economic Affairs of 26 June 2015, no. WJZ/15055654, amending the Space Activities Licence Application and Registration Order, in connection with changes to the application form'},
#  {'country': 'Netherlands',
#   'name': 'Order by the Minister of Economic Affairs of 26 June 2015, no. WJZ/15055654, amending the Space Activities Licence Application and Registration Order, in connection with changes to the application form'},
#  {'country': 'Netherlands',
#   'name': 'Order by the Minister of Economic Affairs of 26 June 2015, no. WJZ/15055654, amending the Space Activities Licence Application and Registration Order, in connection with changes to the application form'},
#  {'country': 'Norway',
#   'name': 'No. 38, 13 June 1969, Act on Launching Objects from Norwegian Territory into Outer Space'},
#  {'country': 'Republic of Korea', 'name': 'Space Liability Act'},
#  {'country': 'Republic of Korea', 'name': 'Space Liability Act'},
#  {'country': 'Russian Federation',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Russian Federation',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Russian Federation',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Russian Federation',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Russian Federation',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Russian Federation',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Russian Federation',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'South Africa', 'name': 'National Space Policy, 2008'},
#  {'country': 'South Africa', 'name': 'National Space Policy, 2008'},
#  {'country': 'South Africa', 'name': 'National Space Policy, 2008'},
#  {'country': 'South Africa', 'name': 'National Space Policy, 2008'},
#  {'country': 'South Africa', 'name': 'National Space Policy, 2008'},
#  {'country': 'Spain',
#   'name': 'ROYAL DECREE 278/1995, dated 24th February 1995, establishing in the Kingdom of Spain of the Registry foreseen in the Convention adopted by the United Nations General Assembly on 2nd November 1974\n  '},
#  {'country': 'Sweden', 'name': 'Decree on Space Activities (1982:1069)\n  '},
#  {'country': 'Sweden', 'name': 'Decree on Space Activities (1982:1069)\n  '},
#  {'country': 'Ukraine',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Ukraine',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Ukraine',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Ukraine',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Ukraine',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Ukraine',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Ukraine',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'Ukraine',
#   'name': 'Agreement between the Government of the Russian Federation and the Cabinet of Ministers of Ukraine on Technology Safeguards Associated with Cooperation in the Field of the Exploration and Use of Outer Space for Peaceful Purposes and in the Development and Operation of Space Rocket and Rocket Equipment'},
#  {'country': 'United Kingdom of Great Britain and Northern Ireland',
#   'name': 'OUTER SPACE ACT (United Kingdom, 1986)\n  '},
#  {'country': 'United States of America',
#   'name': '35 USC Chapter 10, Sect. 105, Inventions in outer space\n  '},
#  {'country': 'United States of America',
#   'name': '35 USC Chapter 10, Sect. 105, Inventions in outer space\n  '}]
