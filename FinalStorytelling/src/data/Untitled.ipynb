# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt 
import re
from cycler import cycler 
import os
import numpy as np

pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv("treaty1celestial.csv")

# %%
df['Date_of_Notification/Deposit'] = pd.to_datetime(df['Date_of_Notification/Deposit'], format='%d/%m/%Y')

# %%
df = df.sort_values(by='Date_of_Notification/Deposit',ascending=True)

# %%
df.drop_duplicates(subset=None, keep='last', inplace=True)

# %%
df.to_csv("CelestialTreaty.csv" , index=False)

# %%
df['Action'].unique()
# Out:
# array(['Accession', 'Signature', 'Declaration', 'Ratification',
#        'Succession', 'Territorial application'], dtype=object)

# %%
df[df['Action'] == 'Declaration']
# Out:
#            Participant       Action Date_of_Notification/Deposit  \
# 147  Republic of Korea  Declaration 1967-01-27
#
#     Date_of_Effect
# 147  NaN

# %%
spaceTreaties = pd.read_csv('SpaceTreaties.csv')

# %%
spaceTreaties.shape
# Out:
# (211, 6)

# %%
dropNAtreaties = spaceTreaties.dropna(thresh=2)

# %%
dropNAtreaties.shape
# Out:
# (145, 6)

# %%
dropNAtreaties.Countries.unique()
# Out:
# array(['Afghanistan', 'Algeria', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Benin', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada',
#        'Central African', 'Chile', 'China', 'Colombia', 'Costa Rica',
#        'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', 'North Korea',
#        'Democratic Republic of the Congo', 'Denmark',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Estonia', 'Ethiopia', 'Fiji', 'Finland',
#        'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Holy See', 'Honduras', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
# ...

# %%
dropNAtreaties.Countries.replace({'Bolivia (Plurinational':'Bolivia', 
                                  'Democratic People’s':'North Korea',
                                  'Democratic Republic':'Democratic Republic of the Congo', 
                                  'Iran (Islamic':'Iran', 'Saint Vincent and':'Saint Vincent and the Grenadines', 
                                  'United Kingdom of':'United Kingdom', 
                                  'United Republic of':'Egypt', 
                                  'United States of':'United States',
                                  'Venezuela (Bolivarian':'Venezuela'} , inplace=True)
# Out:
# /Users/TekendraMBP/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/core/generic.py:5886: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
#Countries	OST	ARRA	LIAB	REG	MOON

dropNAtreaties.MOON.unique()
# Out:
# array([nan, 'R', 'S'], dtype=object)

# %%
dropNAtreaties.fillna('NA', inplace=True)
# Out:
# /Users/TekendraMBP/.pyenv/versions/3.6.4/lib/python3.6/site-packages/pandas/core/frame.py:3790: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
dropNAtreaties
# Out:
#                   Countries OST ARRA LIAB REG MOON
# 0    Afghanistan             R   NA   NA   NA  NA
# 2    Algeria                 R   NA   R    R   NA
# 5    Antigua and Barbuda     R   R    R    R   NA
# 6    Argentina               R   R    R    R   NA
# 7    Armenia                 NA  NA   NA   R   R
# 8    Australia               R   R    R    R   R
# 9    Austria                 R   R    R    R   R
# 10   Azerbaijan              R   NA   NA   NA  NA
# 11   Bahamas                 R   R    NA   NA  NA
# 13   Bangladesh              R   NA   NA   NA  NA
# 14   Barbados                R   R    NA   NA  NA
# 15   Belarus                 R   R    R    R   NA
# 16   Belgium                 R   R    R    R   R
# 18   Benin                   R   NA   R    NA  NA
# 20   Bolivia                 S   S    NA   NA  NA
# 22   Bosnia and Herzegovina  NA  R    R    NA  NA
# 23   Botswana                S   R    R    NA  NA
# 24   Brazil                  R   R    R    R   NA
# ...

# %%
dropNAtreaties.to_csv('spaceTreatiesCleaned.csv', index=False)
